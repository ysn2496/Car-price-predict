# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json
import re

# Load the Excel file and the specific sheet
file_path = 'D:/Project 3 Cardheko/jaipur_cars.xlsx'
df = pd.read_excel(file_path)

# Function to convert Python-style dictionary strings to valid JSON
def convert_to_json_format(text):
    text = text.replace("'", '"').replace("None", "null").replace("True", "true").replace("False", "false")
    text = re.sub(r'(?<!")(\b\w+\b)(?=:)', r'"\1"', text)
    return text

# Apply the conversion to the 'new_car_detail' column
df['new_car_detail'] = df['new_car_detail'].apply(convert_to_json_format)

# Function to flatten the JSON data
def flatten_json_column(df, column_name):
    return pd.json_normalize(df[column_name].apply(json.loads))

# Flatten the 'new_car_detail' column
flattened_details = flatten_json_column(df, 'new_car_detail')

# Display the structured data
flattened_details.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  centralVariantId           variantName  \
# 0        Hyundai i20       2015              1487         Asta 1.4 CRDi
# 1       Maruti Swift       2012             10403                   VXI
# 2     Maruti Celerio       2016              3982                VXI AT
# 3  Hyundai Grand i10       2017              5602  1.2 Kappa Magna BSIV
# 4     Maruti Wagon R       2016              4319               AMT VXI
#
#          price priceActual priceSaving priceFixedText  \
# 0  ₹ 5.10 Lakh                                   None
# 1  ₹ 3.81 Lakh                                   None
# 2  ₹ 3.20 Lakh                                   None
# 3  ₹ 4.20 Lakh                                   None
# 4  ₹ 3.50 Lakh                                   None
#
#                                  trendingText.imgUrl trendingText.heading  \
# 0  https://stimg.cardekho.com/used-cars/common/ic...        Trending Car!
# 1  https://stimg.cardekho.com/used-cars/common/ic...        Trending Car!
# 2  https://stimg.cardekho.com/used-cars/common/ic...        Trending Car!
# 3  https://stimg.cardekho.com/used-cars/common/ic...        Trending Car!
# 4  https://stimg.cardekho.com/used-cars/common/ic...        Trending Car!
#
#                      trendingText.desc
# 0  High chances of sale in next 6 days
# 1  High chances of sale in next 6 days
# 2  High chances of sale in next 6 days
# 3  High chances of sale in next 6 days
# 4  High chances of sale in next 6 days

# %%
#Optionally, save the structured data to a new CSV file
flattened_details.to_csv('structured_new_car_details4.csv', index=False)

# %%
import pandas as pd
import json
import re

# Load the Excel file and the specific sheet
file_path = 'D:/Project 3 Cardheko/jaipur_cars.xlsx'
df = pd.read_excel(file_path)
df['new_car_overview'] = df['new_car_overview'].apply(lambda x:json.loads(x.replace("'",'"').replace('None',"1")))
def car_overview_dict_creator(overview):
    all_overviews = {}
    for dictionary in overview['top']:
        all_overviews.update({dictionary.get('key'):dictionary.get('value')})
    return all_overviews

df.new_car_overview = df.new_car_overview.apply(lambda overview: car_overview_dict_creator(overview))

overview_df = pd.DataFrame(df.new_car_overview.to_list())
overview_df
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2015  Third Party insurance    Diesel  5 Seats
# 1             Jan 2012            Third Party    Petrol  5 Seats
# 2                 2016  Third Party insurance    Petrol  5 Seats
# 3             Apr 2017  Third Party insurance    Petrol  5 Seats
# 4                 2016  Third Party insurance    Petrol  5 Seats
# ...                ...                    ...       ...      ...
# 1115              2011  Third Party insurance    Petrol  5 Seats
# 1116              2007  Third Party insurance    Petrol  5 Seats
# 1117              2022  Third Party insurance    Petrol  5 Seats
# 1118              2009  Third Party insurance    Petrol  5 Seats
# 1119              2018  Third Party insurance    Petrol  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0     1,20,000 Kms  RJ13  Second Owner             1396 cc       Manual
# 1       66,951 Kms  RJ14   First Owner             1197 cc       Manual
# 2       80,000 Kms  RJ14  Second Owner              998 cc    Automatic
# 3       44,392 Kms  RJ14   First Owner             1197 cc       Manual
# 4       40,000 Kms  RJ14   First Owner              998 cc    Automatic
# ...            ...   ...           ...                 ...          ...
# 1115  1,20,000 Kms  RJ14   First Owner             1199 cc       Manual
# 1116    70,000 Kms  RJ30   First Owner              796 cc       Manual
# 1117    20,000 Kms  RJ45   First Owner              999 cc       Manual
# 1118    40,000 Kms   NaN   First Owner              796 cc       Manual
# 1119    80,000 Kms  UP82   First Owner             1197 cc       Manual
#
#       Year of Manufacture
# 0                  2015.0
# 1                  2012.0
# 2                  2016.0
# 3                  2017.0
# 4                  2016.0
# ...                   ...
# 1115               2011.0
# 1116               2007.0
# 1117               2022.0
# 1118               2009.0
# 1119               2018.0
#
# [1120 rows x 10 columns]

# %%
overview_df.to_csv('structured_new_car_overview4.csv', index=False)

# %%
import pandas as pd
import json

# Load the Excel file
file_path = 'D:/Project 3 Cardheko/jaipur_cars.xlsx'
df = pd.read_excel(file_path)

# Clean and parse JSON-like strings in 'new_car_feature'
df['new_car_feature'] = df['new_car_feature'].apply(lambda x: json.loads(x.replace("'", '"').replace('None', '1')))

# Function to flatten the 'new_car_feature' column
def flatten_car_feature(feature):
    # Extract 'commonIcon'
    common_icon = feature.get('commonIcon', None)
    
    # Extract 'top' features
    top_features = {f"Top Feature {i+1}": item['value'] for i, item in enumerate(feature.get('top', []))}
    
    # Extract 'data' features with headings and subheadings
    data_features = {}
    for group in feature.get('data', []):
        heading = group['heading']
        sub_heading = group['subHeading']
        for i, item in enumerate(group.get('list', [])):
            key = f"{heading}_{sub_heading}_Feature {i+1}"
            data_features[key] = item['value']
    
    return {**top_features, **data_features, 'commonIcon': common_icon}

# Apply the function to extract and flatten data from 'new_car_feature'
df['flattened_features'] = df['new_car_feature'].apply(flatten_car_feature)

# Convert the flattened features into a DataFrame
features_df = pd.DataFrame(df['flattened_features'].tolist())

# Concatenate the original DataFrame with the new features DataFrame
result_df = pd.concat([df.drop(columns=['new_car_feature', 'flattened_features']), features_df], axis=1)

# Display the resulting DataFrame
print("Final DataFrame with all features in columns, including commonIcon:")
result_df.head()
# Out:
# Final DataFrame with all features in columns, including commonIcon:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links   Top Feature 1  \
# 0  https://www.cardekho.com/used-car-details/used...  Power Steering
# 1  https://www.cardekho.com/buy-used-car-details/...  Power Steering
# 2  https://www.cardekho.com/used-car-details/used...  Power Steering
# 3  https://www.cardekho.com/buy-used-car-details/...  Power Steering
# 4  https://www.cardekho.com/used-car-details/used...  Power Steering
#
#          Top Feature 2    Top Feature 3 Top Feature 4           Top Feature 5  \
# 0  Power Windows Front  Air Conditioner        Heater  Adjustable Head Lights
# 1  Power Windows Front  Air Conditioner        Heater  Adjustable Head Lights
# 2  Power Windows Front  Air Conditioner        Heater  Adjustable Head Lights
# 3  Power Windows Front  Air Conditioner        Heater  Adjustable Head Lights
# 4  Power Windows Front  Air Conditioner        Heater  Adjustable Head Lights
#
#                                    Top Feature 6  ...  \
# 0                               Fog Lights Front  ...
# 1     Power Adjustable Exterior Rear View Mirror  ...
# 2  Manually Adjustable Exterior Rear View Mirror  ...
# 3     Power Adjustable Exterior Rear View Mirror  ...
# 4                               Fog Lights Front  ...
#
#   Exterior_Exterior_Feature 24 Exterior_Exterior_Feature 25  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   Safety_Safety_Feature 38 Safety_Safety_Feature 39 Safety_Safety_Feature 40  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#   Safety_Safety_Feature 41 Safety_Safety_Feature 42  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#   Entertainment & Communication_Entertainment_Feature 14  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Exterior_Exterior_Feature 26  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#   Entertainment & Communication_Entertainment_Feature 15
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 146 columns]

# %%
# Optionally, save the structured data to a new CSV file
result_df.to_csv('structured_new_car_feature4.csv', index=False)

# %%
import pandas as pd
import json

# Load the Excel file
file_path = 'D:/Project 3 Cardheko/jaipur_cars.xlsx'
df = pd.read_excel(file_path)

# Clean and parse JSON-like strings in 'new_car_specs'
df['new_car_specs'] = df['new_car_specs'].apply(lambda x: json.loads(x.replace("'", '"').replace('None', '1')))

# Function to flatten the 'new_car_specs' column
def flatten_car_specs(specs):
    # Initialize a dictionary to store the flattened data
    flattened_data = {}
    
    
    
    # Extract 'top' specifications
    for item in specs.get('top', []):
        key = item.get('key')
        value = item.get('value')
        if key:  # Ensure key is not None
            flattened_data[key] = value
    
    # Extract 'data' features with headings and subheadings
    for group in specs.get('data', []):
        for item in group.get('list', []):
            key = item.get('key')
            value = item.get('value')
            if key:  # Ensure key is not None
                flattened_data[key] = value
    
    return flattened_data

# Apply the function to extract and flatten data from 'new_car_specs'
df['flattened_specs'] = df['new_car_specs'].apply(flatten_car_specs)

# Convert the flattened specs into a DataFrame
specs_df = pd.DataFrame(df['flattened_specs'].tolist())

# Concatenate the original DataFrame with the new specs DataFrame
result_df = pd.concat([df.drop(columns=['new_car_specs', 'flattened_specs']), specs_df], axis=1)

# Display the resulting DataFrame
print("Final DataFrame with keys as column names and values as rows:")
result_df.head()
# Out:
# Final DataFrame with keys as column names and values as rows:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                            car_links     Mileage   Engine  \
# 0  https://www.cardekho.com/used-car-details/used...  22.54 kmpl  1396 CC
# 1  https://www.cardekho.com/buy-used-car-details/...  22.38 kmpl  1197 CC
# 2  https://www.cardekho.com/used-car-details/used...   23.1 kmpl   998 CC
# 3  https://www.cardekho.com/buy-used-car-details/...   18.9 kmpl  1197 CC
# 4  https://www.cardekho.com/used-car-details/used...  20.51 kmpl   998 CC
#
#           Max Power    Torque Wheel Size Seats  ... Top Speed   Acceleration  \
# 0  88.73bhp@4000rpm   219.7Nm         16     5  ...  180 Kmph   11.9 Seconds
# 1  88.50bhp@6000rpm     113Nm        NaN     5  ...       NaN            NaN
# 2  67.04bhp@6000rpm      90Nm        NaN     5  ...  150 Kmph  15.05 Seconds
# 3  81.86bhp@6000rpm  113.75nm        NaN     5  ...  165 Kmph   12.9 Seconds
# 4     67bhp@6000rpm      90Nm        NaN     5  ...  152 kmph   18.6 Seconds
#
#           Tyre Type Alloy Wheel Size  No Door Numbers  Cargo Volumn  \
# 0          Tubeless               16                5    295-litres
# 1  Radial, Tubeless              NaN                5           268
# 2  Tubeless, Radial              NaN                5    235-litres
# 3          Tubeless              NaN                5           256
# 4    Tubeless Tyres              NaN                5    180-liters
#
#   Gross Weight BoreX Stroke Compression Ratio Ground Clearance Unladen
# 0          NaN          NaN               NaN                      NaN
# 1         1335          NaN               NaN                      NaN
# 2       1250kg   73 X 82 mm            11.0:1                      NaN
# 3          NaN          NaN               NaN                      NaN
# 4       1350kg   69 x 72 mm               NaN                      NaN
#
# [5 rows x 44 columns]

# %%
# Optionally, save the structured data to a new CSV file
result_df.to_csv('structured_new_car_specs4.csv', index=False)

# %%
df1 = pd.read_csv('D:/Project 3 Cardheko/structured_new_car_details4.csv')
df2 = pd.read_csv('D:/Project 3 Cardheko/structured_new_car_feature4.csv')
df3 = pd.read_csv('D:/Project 3 Cardheko/structured_new_car_overview4.csv')
df4 = pd.read_csv('D:/Project 3 Cardheko/structured_new_car_specs4.csv')

# Concatenate DataFrames horizontally
final_concat_df = pd.concat([df1, df2, df3, df4], axis=1)

# Display the final concatenated DataFrame
final_concat_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...  Top Speed   Acceleration  \
# 0       Hyundai        Hyundai i20       2015  ...   180 Kmph   11.9 Seconds
# 1        Maruti       Maruti Swift       2012  ...        NaN            NaN
# 2        Maruti     Maruti Celerio       2016  ...   150 Kmph  15.05 Seconds
# 3       Hyundai  Hyundai Grand i10       2017  ...   165 Kmph   12.9 Seconds
# 4        Maruti     Maruti Wagon R       2016  ...   152 kmph   18.6 Seconds
# ...         ...                ...        ...  ...        ...            ...
# 1115  Chevrolet     Chevrolet Beat       2011  ...        NaN            NaN
# 1116     Maruti        Maruti Alto       2007  ...   137km/hr   17.7 seconds
# 1117    Renault      Renault Kiger       2022  ...        NaN            NaN
# 1118     Maruti        Maruti Alto       2009  ...   137km/hr   17.7 seconds
# 1119     Maruti      Maruti Baleno       2018  ...   180 Kmph  12.36 seconds
#
#              Tyre Type Alloy Wheel Size  No Door Numbers  Cargo Volumn  \
# 0             Tubeless               16              5.0    295-litres
# 1     Radial, Tubeless              NaN              5.0           268
# 2     Tubeless, Radial              NaN              5.0    235-litres
# 3             Tubeless              NaN              5.0           256
# 4       Tubeless Tyres              NaN              5.0    180-liters
# ...                ...              ...              ...           ...
# 1115   Tubeless,Radial               14              5.0    170-litres
# 1116   Tubeless,Radial               12              5.0           NaN
# 1117  Tubeless, Radial               16              5.0           405
# 1118   Tubeless,Radial               12              5.0           NaN
# 1119   Tubeless,Radial              NaN              5.0    339-litres
#
#      Gross Weight    BoreX Stroke Compression Ratio Ground Clearance Unladen
# 0             NaN             NaN               NaN                      NaN
# 1            1335             NaN               NaN                      NaN
# 2          1250kg      73 X 82 mm            11.0:1                      NaN
# 3             NaN             NaN               NaN                      NaN
# 4          1350kg      69 x 72 mm               NaN                      NaN
# ...           ...             ...               ...                      ...
# 1115          NaN             NaN               NaN                      NaN
# 1116       1140kg  68.5 x 72.0 mm               NaN                      NaN
# 1117          NaN             NaN               NaN                      NaN
# 1118       1140kg  68.5 x 72.0 mm               NaN                      NaN
# 1119       1340kg             NaN               NaN                      NaN
#
# [1120 rows x 219 columns]

# %%
final_concat_df['city'] = 'Jaipur'

# %%
final_concat_df.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  ...   Acceleration         Tyre Type  \
# 0        Hyundai i20       2015  ...   11.9 Seconds          Tubeless
# 1       Maruti Swift       2012  ...            NaN  Radial, Tubeless
# 2     Maruti Celerio       2016  ...  15.05 Seconds  Tubeless, Radial
# 3  Hyundai Grand i10       2017  ...   12.9 Seconds          Tubeless
# 4     Maruti Wagon R       2016  ...   18.6 Seconds    Tubeless Tyres
#
#   Alloy Wheel Size No Door Numbers  Cargo Volumn  Gross Weight BoreX Stroke  \
# 0               16             5.0    295-litres           NaN          NaN
# 1              NaN             5.0           268          1335          NaN
# 2              NaN             5.0    235-litres        1250kg   73 X 82 mm
# 3              NaN             5.0           256           NaN          NaN
# 4              NaN             5.0    180-liters        1350kg   69 x 72 mm
#
#   Compression Ratio Ground Clearance Unladen    city
# 0               NaN                      NaN  Jaipur
# 1               NaN                      NaN  Jaipur
# 2            11.0:1                      NaN  Jaipur
# 3               NaN                      NaN  Jaipur
# 4               NaN                      NaN  Jaipur
#
# [5 rows x 220 columns]

# %%
final_concat_df.to_csv('Jaipur.csv',index=False)
